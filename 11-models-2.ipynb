# %% [markdown]
# # Evaluating Models

# %% [markdown]
# Learning Curves
#
# * It can be shown that *any model* can learn its training data perfectly - “memorize it”
# * But memorizing is not the same as learning inherent patterns and use those patterns to make predictions!
#
# > Memorization does not generalize well!

# %% [markdown]
# If we train a model using *training data* and then apply the model to a *validation data set* then we obtain these following typical curves:
#
# <!-- ![model curves](assets/model-performance-curves.png) -->
#
# <img src="assets/model-performance-curves.png"  height="200" width="400">
#
# Note: Validation data is data that the model has not seen yet.

# %% [markdown]
# Simply put:
#
# 1. Undertrained models make a lot of errors on validation data because they have not learned any of the patterns yet.
#
# 2. Overtrained models (models that have memorized their training data) make a lot of errors on validation data because they believe the noise in the data are patterns.
#
# 3. The best models make a trade-off between errors and recognizing important patterns. Notice that for the best models the training score is not 100%!

# %% [markdown]
# # Train and Test (Validate)

# %% [markdown]
# In order to simulate the fact that a model is not able to see all possible data points during training we split our training data into two parts:
#
# * Training data
# * Testing (validation) data
#
# We will train our model on the training data as before but we will now test the model performance on the testing data which the model has not seen yet.
#
# > That is, we force the model to make some generalizations.

# %% [markdown]
# # Decision Trees: Train and Test

# %%
import pandas as pd
from treeviz import tree_print
from sklearn import tree
from sklearn.metrics import accuracy_score
# sklearn provides manipulation of training sets...here we do train/test split
from sklearn.model_selection import train_test_split

# %% [markdown]
# # The Iris Data Set

# %%
# set up our sklearn data shape for the iris data
df = pd.read_csv("assets/iris.csv")
X  = df.drop(['id','Species'],axis=1)
y = df['Species']

# %%
# set up the tree model object - limit the complexity to put us somewhere in the middle of the graph.
model = tree.DecisionTreeClassifier(criterion='entropy', max_depth=2)

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2)

# fit the model on the training set of data
model.fit(X_train, y_train)

# evaluate the model on the testing set of data
y_test_model = model.predict(X_test)

# output the results
tree_print(model,X)
print("Accuracy: {}".format(accuracy_score(y_test, y_test_model)))
# Out:
# if Petal.Width =< 0.800000011920929:
#   |then setosa
#   |else if Petal.Width =< 1.75:
#   |  |then versicolor
#   |  |else virginica
# <---->
# Tree Depth:  2
# Accuracy: 0.9666666666666667

# %% [markdown]
# # The Abalone Data Set
#
# The Abalone data set is available from [UCI](http://archive.ics.uci.edu/ml/datasets/Abalone).

# %%
df = pd.read_csv("assets/abalone.csv")

# %%
df.shape
# Out:
# (4177, 9)

# %%
df['sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: sex, dtype: int64

# %%
X = df.drop(['sex'],axis=1)
y = df['sex']

# %%
# set up the tree model object - limit the complexity to put us somewhere in the middle of the graph.
model = tree.DecisionTreeClassifier(criterion='entropy', max_depth=6)

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2)

# fit the model on the training set of data
model.fit(X_train, y_train)

# evaluate the model on the testing set of data
y_test_model = model.predict(X_test)

# output the results
tree_print(model,X)
print("Accuracy: {}".format(accuracy_score(y_test, y_test_model)))
# Out:
# if viscera weight =< 0.15625:
#   |then if rings =< 8.5:
#   |  |then if viscera weight =< 0.09325000643730164:
#   |  |  |then if height =< 0.11249999701976776:
#   |  |  |  |then if whole weight =< 0.12524999678134918:
#   |  |  |  |  |then if height =< 0.07250000536441803:
#   |  |  |  |  |  |then I
#   |  |  |  |  |  |else I
#   |  |  |  |  |else if viscera weight =< 0.023749999701976776:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else I
#   |  |  |  |else if height =< 0.12250000238418579:
#   |  |  |  |  |then if viscera weight =< 0.08449999988079071:
#   |  |  |  |  |  |then I
#   |  |  |  |  |  |else M
#   |  |  |  |  |else if viscera weight =< 0.08275000005960464:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else I
#   |  |  |else if viscera weight =< 0.13124999403953552:
#   |  |  |  |then if shucked weight =< 0.15575000643730164:
#   |  |  |  |  |then if height =< 0.10249999910593033:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else F
#   |  |  |  |  |else if shell weight =< 0.10924999415874481:
#   |  |  |  |  |  |then I
#   |  |  |  |  |  |else I
#   |  |  |  |else if viscera weight =< 0.14374999701976776:
#   |  |  |  |  |then if diameter =< 0.4124999940395355:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else I
#   |  |  |  |  |else if shucked weight =< 0.30900001525878906:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else M
#   |  |else if rings =< 9.5:
#   |  |  |then if viscera weight =< 0.15474998950958252:
#   |  |  |  |then if length =< 0.5475000143051147:
#   |  |  |  |  |then if whole weight =< 0.7722499966621399:
#   |  |  |  |  |  |then I
#   |  |  |  |  |  |else M
#   |  |  |  |  |else if length =< 0.5724999904632568:
#   |  |  |  |  |  |then I
#   |  |  |  |  |  |else I
#   |  |  |  |else if shucked weight =< 0.28025001287460327:
#   |  |  |  |  |then I
#   |  |  |  |  |else M
#   |  |  |else if shell weight =< 0.07175000011920929:
#   |  |  |  |then if viscera weight =< 0.05049999803304672:
#   |  |  |  |  |then if viscera weight =< 0.035499997437000275:
#   |  |  |  |  |  |then I
#   |  |  |  |  |  |else M
#   |  |  |  |  |else I
#   |  |  |  |else if rings =< 11.5:
#   |  |  |  |  |then if length =< 0.5074999928474426:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else I
#   |  |  |  |  |else if shell weight =< 0.2134999930858612:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else M
#   |else if whole weight =< 0.9897500276565552:
#   |  |then if shucked weight =< 0.24774999916553497:
#   |  |  |then if diameter =< 0.38749998807907104:
#   |  |  |  |then if shell weight =< 0.2044999897480011:
#   |  |  |  |  |then M
#   |  |  |  |  |else if viscera weight =< 0.17149999737739563:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else M
#   |  |  |  |else if whole weight =< 0.7682499885559082:
#   |  |  |  |  |then if viscera weight =< 0.16725000739097595:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else F
#   |  |  |  |  |else M
#   |  |  |else if whole weight =< 0.8610000014305115:
#   |  |  |  |then if length =< 0.5375000238418579:
#   |  |  |  |  |then if whole weight =< 0.6832500100135803:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else M
#   |  |  |  |  |else if viscera weight =< 0.1587499976158142:
#   |  |  |  |  |  |then I
#   |  |  |  |  |  |else M
#   |  |  |  |else if shucked weight =< 0.3487499952316284:
#   |  |  |  |  |then if length =< 0.5774999856948853:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else F
#   |  |  |  |  |else if shell weight =< 0.2057499885559082:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else M
#   |  |else if viscera weight =< 0.2682499885559082:
#   |  |  |then if rings =< 15.5:
#   |  |  |  |then if shell weight =< 0.34450000524520874:
#   |  |  |  |  |then if whole weight =< 1.1549999713897705:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else M
#   |  |  |  |  |else if shucked weight =< 0.3790000081062317:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else F
#   |  |  |  |else if length =< 0.6524999737739563:
#   |  |  |  |  |then if shucked weight =< 0.5297499895095825:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else I
#   |  |  |  |  |else M
#   |  |  |else if shucked weight =< 0.8732500076293945:
#   |  |  |  |then if diameter =< 0.5274999737739563:
#   |  |  |  |  |then if viscera weight =< 0.2852500081062317:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else F
#   |  |  |  |  |else if shell weight =< 0.5975000262260437:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else F
#   |  |  |  |else if length =< 0.7774999737739563:
#   |  |  |  |  |then if height =< 0.17249999940395355:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else M
#   |  |  |  |  |else F
# <---------------->
# Tree Depth:  6
# Accuracy: 0.534688995215311

# %% [markdown]
# Let's try the same thing on just the training data...we expect trouble...

# %%
# set up the tree model object
model = tree.DecisionTreeClassifier(criterion='entropy', max_depth=None)

# fit the model on the training set
model.fit(X, y)

# evaluate the model on the training set 
y_model = model.predict(X)

# output the results
tree_print(model,X)
print("Accuracy: {}".format(accuracy_score(y, y_model)))
# Out:
# if viscera weight =< 0.16224999725818634:
#   |then if rings =< 8.5:
#   |  |then if viscera weight =< 0.09325000643730164:
#   |  |  |then if whole weight =< 0.1394999921321869:
#   |  |  |  |then if shucked weight =< 0.05550000071525574:
#   |  |  |  |  |then if rings =< 6.5:
#   |  |  |  |  |  |then if height =< 0.07250000536441803:
#   |  |  |  |  |  |  |then if viscera weight =< 0.009749999269843102:
#   |  |  |  |  |  |  |  |then if height =< 0.03750000149011612:
#   |  |  |  |  |  |  |  |  |then if rings =< 4.5:
#   |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |else if length =< 0.1574999988079071:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |else if whole weight =< 0.016499999910593033:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.008249999955296516:
#   |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.025499999523162842:
#   |  |  |  |  |  |  |  |  |  |  |  |then if rings =< 5.0:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.007249999791383743:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if rings =< 4.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if height =< 0.04749999940395355:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.010499999858438969:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.03400000184774399:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.00925000011920929:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.04574999958276749:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |else if height =< 0.0625:
#   |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |else if whole weight =< 0.09650000184774399:
#   |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.03225000202655792:
#   |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.020750001072883606:
#   |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.06399999558925629:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.024250000715255737:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.03424999862909317:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.02524999901652336:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.20499999821186066:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.2824999988079071:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |else if whole weight =< 0.12074999511241913:
#   |  |  |  |  |  |  |  |then if whole weight =< 0.08900000154972076:
#   |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |else if viscera weight =< 0.028749998658895493:
#   |  |  |  |  |  |  |  |  |  |then if diameter =< 0.20250000059604645:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else if length =< 0.2775000035762787:
#   |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.11675000190734863:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.2824999988079071:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.026250001043081284:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |else if viscera weight =< 0.012000000104308128:
#   |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |else if shell weight =< 0.035499997437000275:
#   |  |  |  |  |  |  |  |then if whole weight =< 0.0820000022649765:
#   |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |else if viscera weight =< 0.026250001043081284:
#   |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.026999998837709427:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else if viscera weight =< 0.030500000342726707:
#   |  |  |  |  |  |  |  |  |then if rings =< 7.5:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else if height =< 0.08249999582767487:
#   |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |else I
#   |  |  |  |else if height =< 0.11249999701976776:
#   |  |  |  |  |then if length =< 0.38749998807907104:
#   |  |  |  |  |  |then if viscera weight =< 0.0507500022649765:
#   |  |  |  |  |  |  |then if viscera weight =< 0.024000000208616257:
#   |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |else if shucked weight =< 0.09974999725818634:
#   |  |  |  |  |  |  |  |  |then if viscera weight =< 0.03375000134110451:
#   |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.07249999791383743:
#   |  |  |  |  |  |  |  |  |  |  |then if length =< 0.3075000047683716:
#   |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.1469999998807907:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |else if length =< 0.3675000071525574:
#   |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.05274999886751175:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.07074999809265137:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if height =< 0.08249999582767487:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.23250000178813934:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.04725000262260437:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.03424999862909317:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if rings =< 7.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.32249999046325684:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.05250000208616257:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.07175000011920929:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.24250000715255737:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.035499997437000275:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.3199999928474426:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.04124999791383743:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.32749998569488525:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if rings =< 5.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.085999995470047:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.041749998927116394:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if height =< 0.0949999988079071:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.18324999511241913:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.22325000166893005:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.19350001215934753:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.1862500011920929:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.26499998569488525:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if height =< 0.08249999582767487:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.27250000834465027:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.06874999403953552:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |else if diameter =< 0.30250000953674316:
#   |  |  |  |  |  |  |  |then if viscera weight =< 0.05324999988079071:
#   |  |  |  |  |  |  |  |  |then if shell weight =< 0.06849999725818634:
#   |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.22299998998641968:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.2874999940395355:
#   |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else if height =< 0.09749999642372131:
#   |  |  |  |  |  |  |  |  |  |then if diameter =< 0.26749998331069946:
#   |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.26249998807907104:
#   |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.06724999845027924:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.07899999618530273:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.049000002443790436:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.35500001907348633:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |else if height =< 0.08750000596046448:
#   |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.27775001525878906:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.07099999487400055:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.2775000035762787:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |else if diameter =< 0.29249998927116394:
#   |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.07324999570846558:
#   |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |else if rings =< 6.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.2824999988079071:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.10875000059604645:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.07874999940395355:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.11900000274181366:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.29750001430511475:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else if shucked weight =< 0.1380000114440918:
#   |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |else if shell weight =< 0.11550000309944153:
#   |  |  |  |  |  |  |then if height =< 0.10249999910593033:
#   |  |  |  |  |  |  |  |then if shucked weight =< 0.17350000143051147:
#   |  |  |  |  |  |  |  |  |then if shucked weight =< 0.17024999856948853:
#   |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.07950000464916229:
#   |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.3357499837875366:
#   |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.3345000147819519:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.0989999994635582:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.060499999672174454:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.2874999940395355:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.4025000035762787:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.2615000009536743:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.15299999713897705:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.07224999368190765:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.4025000035762787:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |else if length =< 0.4325000047683716:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |else if shucked weight =< 0.25550001859664917:
#   |  |  |  |  |  |  |  |then if shucked weight =< 0.17524999380111694:
#   |  |  |  |  |  |  |  |  |then if whole weight =< 0.42899999022483826:
#   |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.11800000071525574:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else if height =< 0.08749999850988388:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |else if diameter =< 0.35249999165534973:
#   |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.18549999594688416:
#   |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.12725000083446503:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.11800000071525574:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else M
#   |  |  |  |  |else if height =< 0.12250000238418579:
#   |  |  |  |  |  |then if viscera weight =< 0.08449999988079071:
#   |  |  |  |  |  |  |then if rings =< 7.5:
#   |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |else if viscera weight =< 0.05874999985098839:
#   |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |else if shell weight =< 0.13350000977516174:
#   |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.06875000149011612:
#   |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.07125000655651093:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.08750000596046448:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.20600000023841858:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.41624999046325684:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |else if diameter =< 0.3425000011920929:
#   |  |  |  |  |  |  |  |then if whole weight =< 0.382999986410141:
#   |  |  |  |  |  |  |  |  |then if whole weight =< 0.35600000619888306:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |else if shucked weight =< 0.2840000092983246:
#   |  |  |  |  |  |  |  |  |then if diameter =< 0.3700000047683716:
#   |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.19949999451637268:
#   |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |else if viscera weight =< 0.09125000238418579:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |else if viscera weight =< 0.08275000005960464:
#   |  |  |  |  |  |  |then if length =< 0.38749998807907104:
#   |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |else if rings =< 7.5:
#   |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |else if whole weight =< 0.3622500002384186:
#   |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |else I
#   |  |  |else if whole weight =< 0.6389999985694885:
#   |  |  |  |then if shucked weight =< 0.15575000643730164:
#   |  |  |  |  |then if height =< 0.10249999910593033:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else if whole weight =< 0.38099998235702515:
#   |  |  |  |  |  |  |then if rings =< 7.5:
#   |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |else F
#   |  |  |  |  |else if shell weight =< 0.10924999415874481:
#   |  |  |  |  |  |then I
#   |  |  |  |  |  |else if length =< 0.4724999964237213:
#   |  |  |  |  |  |  |then if shucked weight =< 0.2695000171661377:
#   |  |  |  |  |  |  |  |then if shucked weight =< 0.20675000548362732:
#   |  |  |  |  |  |  |  |  |then if shell weight =< 0.12825000286102295:
#   |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.10500000417232513:
#   |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |else if height =< 0.12000000476837158:
#   |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |else if diameter =< 0.35249999165534973:
#   |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.20024999976158142:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.13625000417232513:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.45750001072883606:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.19300000369548798:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.10575000196695328:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.12999999523162842:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.2057500034570694:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.10750000178813934:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.18424999713897705:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else if shell weight =< 0.14399999380111694:
#   |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.11474999785423279:
#   |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.10975000262260437:
#   |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.20800000429153442:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.4950000047683716:
#   |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.1394999921321869:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.4650000035762787:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |else if diameter =< 0.3725000023841858:
#   |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.22075000405311584:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.21150000393390656:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.1574999988079071:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.1417500078678131:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if height =< 0.10750000178813934:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.22100000083446503:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.2357499897480011:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.3824999928474426:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else if whole weight =< 0.5839999914169312:
#   |  |  |  |  |  |  |  |  |then if rings =< 6.5:
#   |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else if shell weight =< 0.13750000298023224:
#   |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.27425000071525574:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |else if viscera weight =< 0.10725000500679016:
#   |  |  |  |  |  |  |  |then if shucked weight =< 0.19249999523162842:
#   |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |else if height =< 0.10249999910593033:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else if height =< 0.1274999976158142:
#   |  |  |  |  |  |  |  |  |  |  |then if rings =< 7.5:
#   |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.48250001668930054:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.10225000232458115:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.47749999165534973:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.10074999928474426:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.38749998807907104:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.09524999558925629:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.10050000250339508:
#   |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |else if whole weight =< 0.5212500095367432:
#   |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |else if shell weight =< 0.15524999797344208:
#   |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.11625000089406967:
#   |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.13899999856948853:
#   |  |  |  |  |  |  |  |  |  |  |  |then if rings =< 7.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.3147500157356262:
#   |  |  |  |  |  |  |  |  |  |  |  |then if rings =< 7.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.5024999976158142:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.47749999165534973:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.12924998998641968:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.1419999897480011:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.3824999928474426:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.3700000047683716:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.5224999785423279:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.14750000834465027:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.13449999690055847:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.6262500286102295:
#   |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.13100001215934753:
#   |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.47749999165534973:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.2212499976158142:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.39750000834465027:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.1782499998807907:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.17249999940395355:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.1210000067949295:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.25174999237060547:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.5759999752044678:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.22475001215934753:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if rings =< 7.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.14675000309944153:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if height =< 0.1274999976158142:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.48750001192092896:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.29224997758865356:
#   |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.48750001192092896:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |else if rings =< 7.5:
#   |  |  |  |  |then if length =< 0.47749999165534973:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else if diameter =< 0.4350000023841858:
#   |  |  |  |  |  |  |then if viscera weight =< 0.15775001049041748:
#   |  |  |  |  |  |  |  |then if shucked weight =< 0.4165000021457672:
#   |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else if height =< 0.13249999284744263:
#   |  |  |  |  |  |  |  |  |then if viscera weight =< 0.16124999523162842:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |else if height =< 0.1274999976158142:
#   |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |else I
#   |  |  |  |  |else if shucked weight =< 0.39925000071525574:
#   |  |  |  |  |  |then if length =< 0.5375000238418579:
#   |  |  |  |  |  |  |then if shucked weight =< 0.31450000405311584:
#   |  |  |  |  |  |  |  |then if shucked weight =< 0.2952499985694885:
#   |  |  |  |  |  |  |  |  |then if shell weight =< 0.18649999797344208:
#   |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else if whole weight =< 0.6977499723434448:
#   |  |  |  |  |  |  |  |  |  |then if length =< 0.5149999856948853:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |else if shell weight =< 0.1537500023841858:
#   |  |  |  |  |  |  |  |  |then if shucked weight =< 0.3700000047683716:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |else if whole weight =< 0.718500018119812:
#   |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.12424999475479126:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.18649999797344208:
#   |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.3460000157356262:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |else if height =< 0.14249999821186066:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |else if shucked weight =< 0.3177499771118164:
#   |  |  |  |  |  |  |  |then if whole weight =< 0.6514999866485596:
#   |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |else if diameter =< 0.4375:
#   |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |else if shell weight =< 0.2522500157356262:
#   |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |else if height =< 0.13500000536441803:
#   |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |else F
#   |  |else if rings =< 9.5:
#   |  |  |then if length =< 0.42750000953674316:
#   |  |  |  |then if length =< 0.42250001430511475:
#   |  |  |  |  |then if length =< 0.41749998927116394:
#   |  |  |  |  |  |then if viscera weight =< 0.045249998569488525:
#   |  |  |  |  |  |  |then if viscera weight =< 0.038750000298023224:
#   |  |  |  |  |  |  |  |then if length =< 0.32249999046325684:
#   |  |  |  |  |  |  |  |  |then if shucked weight =< 0.04699999839067459:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |else if shucked weight =< 0.07275000214576721:
#   |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |else if whole weight =< 0.19624999165534973:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |else if diameter =< 0.26749998331069946:
#   |  |  |  |  |  |  |  |then if viscera weight =< 0.054999999701976776:
#   |  |  |  |  |  |  |  |  |then if shell weight =< 0.054999999701976776:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else if shucked weight =< 0.10249999910593033:
#   |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |else if whole weight =< 0.273499995470047:
#   |  |  |  |  |  |  |  |  |  |then if length =< 0.3675000071525574:
#   |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |else if height =< 0.09749999642372131:
#   |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.0925000011920929:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.35199999809265137:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.13224999606609344:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.29624998569488525:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.1574999988079071:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.06399999558925629:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |else I
#   |  |  |  |  |else M
#   |  |  |  |else if whole weight =< 0.7752500176429749:
#   |  |  |  |  |then if length =< 0.5475000143051147:
#   |  |  |  |  |  |then if shucked weight =< 0.3292500078678131:
#   |  |  |  |  |  |  |then if length =< 0.5074999928474426:
#   |  |  |  |  |  |  |  |then if whole weight =< 0.6232500076293945:
#   |  |  |  |  |  |  |  |  |then if shucked weight =< 0.18724998831748962:
#   |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.08024999499320984:
#   |  |  |  |  |  |  |  |  |  |  |then if length =< 0.44749999046325684:
#   |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.06325000524520874:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.45249998569488525:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if height =< 0.10750000178813934:
#   |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.45249998569488525:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.4675000011920929:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.35750001668930054:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.13349999487400055:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.3449999988079071:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.11499999463558197:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 0.37950000166893005:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.35249999165534973:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.4560000002384186:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.14249999821186066:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.49000000953674316:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.1132500022649765:
#   |  |  |  |  |  |  |  |  |  |  |then if length =< 0.4675000011920929:
#   |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.08550000190734863:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.45524999499320984:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.101500004529953:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.47874999046325684:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.1394999921321869:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.10750000178813934:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.5927500128746033:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.11149999499320984:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.5502500534057617:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |else if length =< 0.4925000071525574:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.14750000834465027:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.1342500001192093:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if height =< 0.11749999970197678:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.11675000190734863:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.48000001907348633:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if diameter =< 0.3675000071525574:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.16850000619888306:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.531499981880188:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.16749998927116394:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.20250000059604645:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else if whole weight =< 0.6644999980926514:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else if length =< 0.5024999976158142:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |else if viscera weight =< 0.1262499988079071:
#   |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |else if height =< 0.13750000298023224:
#   |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.20675000548362732:
#   |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.2645000219345093:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.20724999904632568:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.24674999713897705:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.5325000286102295:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.6507500410079956:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if height =< 0.13249999284744263:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.14750000834465027:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.7007499933242798:
#   |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |else if height =< 0.14750000834465027:
#   |  |  |  |  |  |  |  |  |  |  |then if length =< 0.5174999833106995:
#   |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.14399999380111694:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.13300000131130219:
#   |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |else if viscera weight =< 0.1417500078678131:
#   |  |  |  |  |  |  |  |then if shucked weight =< 0.34074997901916504:
#   |  |  |  |  |  |  |  |  |then if diameter =< 0.4025000035762787:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else if length =< 0.5074999928474426:
#   |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |else if viscera weight =< 0.14425000548362732:
#   |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.14300000667572021:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |else if height =< 0.17000000178813934:
#   |  |  |  |  |  |  |then if shell weight =< 0.203000009059906:
#   |  |  |  |  |  |  |  |then if height =< 0.1274999976158142:
#   |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |else F
#   |  |  |  |  |else if shell weight =< 0.226500004529953:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else if viscera weight =< 0.15775001049041748:
#   |  |  |  |  |  |  |then if viscera weight =< 0.1537500023841858:
#   |  |  |  |  |  |  |  |then if diameter =< 0.4424999952316284:
#   |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |else if shucked weight =< 0.34299999475479126:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |else if whole weight =< 0.8277499675750732:
#   |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |else I
#   |  |  |else if shucked weight =< 0.07349999994039536:
#   |  |  |  |then if viscera weight =< 0.035499997437000275:
#   |  |  |  |  |then if shucked weight =< 0.0625:
#   |  |  |  |  |  |then M
#   |  |  |  |  |  |else I
#   |  |  |  |  |else M
#   |  |  |  |else if shell weight =< 0.28325000405311584:
#   |  |  |  |  |then if shucked weight =< 0.3022499978542328:
#   |  |  |  |  |  |then if viscera weight =< 0.10924999415874481:
#   |  |  |  |  |  |  |then if viscera weight =< 0.10774999856948853:
#   |  |  |  |  |  |  |  |then if height =< 0.14249999821186066:
#   |  |  |  |  |  |  |  |  |then if viscera weight =< 0.09074999392032623:
#   |  |  |  |  |  |  |  |  |  |then if height =< 0.08750000596046448:
#   |  |  |  |  |  |  |  |  |  |  |then if height =< 0.07249999791383743:
#   |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |else if length =< 0.4325000047683716:
#   |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.06450000405311584:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.09974999725818634:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.0832500010728836:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if rings =< 10.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if height =< 0.09749999642372131:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.08150000125169754:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.039000000804662704:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.08874999731779099:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.3974999785423279:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.07375000417232513:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.25450000166893005:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.39249998331069946:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if height =< 0.11499999463558197:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.06024999916553497:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.1392499953508377:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if height =< 0.09749999642372131:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 0.3842499852180481:
# ...
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 1.371999979019165:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.3147500157356262:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.6187499761581421:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.5950000286102295:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.5614999532699585:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.637499988079071:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 1.3287500143051147:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.30049997568130493:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 1.308000087738037:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.47749999165534973:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.5687500238418579:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if rings =< 16.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if height =< 0.1875:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if rings =< 12.0:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 1.308500051498413:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.36024999618530273:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 1.3680000305175781:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 1.3692500591278076:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |else if rings =< 15.5:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.6107500195503235:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.6232500076293945:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.706250011920929:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.31725001335144043:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 1.3787500858306885:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |else if shucked weight =< 0.6890000104904175:
#   |  |  |  |  |  |  |  |  |then if whole weight =< 1.433500051498413:
#   |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |else if rings =< 11.5:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |else if rings =< 12.5:
#   |  |  |  |  |  |  |  |then if whole weight =< 1.7639999389648438:
#   |  |  |  |  |  |  |  |  |then if length =< 0.637499988079071:
#   |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.4179999828338623:
#   |  |  |  |  |  |  |  |  |  |  |then if length =< 0.6974999904632568:
#   |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.3527500033378601:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if rings =< 10.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 1.4927499294281006:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if height =< 0.17750000953674316:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.6772500276565552:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.4039999842643738:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.4037500023841858:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.6894999742507935:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.3855000138282776:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.4102500081062317:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.5174999833106995:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.675000011920929:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if height =< 0.1899999976158142:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.44225001335144043:
#   |  |  |  |  |  |  |  |  |  |  |  |then if viscera weight =< 0.3412500023841858:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.6474999785423279:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.7649999856948853:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 1.4900000095367432:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.6825000047683716:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.6725000143051147:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.4520000219345093:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.3632500171661377:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.6897499561309814:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |else if length =< 0.6424999833106995:
#   |  |  |  |  |  |  |  |  |then if shucked weight =< 0.7024999856948853:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |  |  |  |else if rings =< 14.5:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else if diameter =< 0.5224999785423279:
#   |  |  |  |  |  |  |  |  |  |  |then if height =< 0.19749999046325684:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.5199999809265137:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.343999981880188:
#   |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |else I
#   |  |  |  |  |  |else F
#   |  |  |  |  |else if length =< 0.7524999976158142:
#   |  |  |  |  |  |then if height =< 0.18250000476837158:
#   |  |  |  |  |  |  |then if length =< 0.6775000095367432:
#   |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |else if rings =< 13.5:
#   |  |  |  |  |  |  |  |  |then if whole weight =< 1.6727499961853027:
#   |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.6924999952316284:
#   |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.6499999761581421:
#   |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.2849999964237213:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.6792500019073486:
#   |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |else if rings =< 10.5:
#   |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.6974999904632568:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if rings =< 9.5:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |else if diameter =< 0.5525000095367432:
#   |  |  |  |  |  |  |  |then if viscera weight =< 0.4347499907016754:
#   |  |  |  |  |  |  |  |  |then if shucked weight =< 0.7055000066757202:
#   |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.5699999928474426:
#   |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.596500039100647:
#   |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 1.4709999561309814:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else if diameter =< 0.5425000190734863:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 1.6670000553131104:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if length =< 0.6924999952316284:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.6445000171661377:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.3942500054836273:
#   |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.8220000267028809:
#   |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 1.621000051498413:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then if height =< 0.1875:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |else if viscera weight =< 0.3700000047683716:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |else if length =< 0.6875:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.3824999928474426:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |else if rings =< 11.5:
#   |  |  |  |  |  |  |  |  |  |then I
#   |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |else if height =< 0.19749999046325684:
#   |  |  |  |  |  |  |  |  |then if whole weight =< 1.6524999141693115:
#   |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.4542499780654907:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |else if shell weight =< 0.42250001430511475:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else if length =< 0.6924999952316284:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else if rings =< 19.5:
#   |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.6625000238418579:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if length =< 0.7124999761581421:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if whole weight =< 1.8459999561309814:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.7177499532699585:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.5874999761581421:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shucked weight =< 0.7357500195503235:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else if whole weight =< 2.226749897003174:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |else M
#   |  |  |  |else if diameter =< 0.6225000023841858:
#   |  |  |  |  |then if shell weight =< 0.624500036239624:
#   |  |  |  |  |  |then if shell weight =< 0.5370000004768372:
#   |  |  |  |  |  |  |then if shucked weight =< 1.0764999389648438:
#   |  |  |  |  |  |  |  |then if height =< 0.17249999940395355:
#   |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |else if viscera weight =< 0.4620000123977661:
#   |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.41449999809265137:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.9240000247955322:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 0.934499979019165:
#   |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |else if shucked weight =< 1.059000015258789:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |then if shell weight =< 0.43024998903274536:
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |else if shell weight =< 0.5249999761581421:
#   |  |  |  |  |  |  |  |  |  |  |then if height =< 0.1899999976158142:
#   |  |  |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |else if whole weight =< 2.3569998741149902:
#   |  |  |  |  |  |  |  |then if height =< 0.2175000011920929:
#   |  |  |  |  |  |  |  |  |then if length =< 0.7150000333786011:
#   |  |  |  |  |  |  |  |  |  |then M
#   |  |  |  |  |  |  |  |  |  |else if length =< 0.7599999904632568:
#   |  |  |  |  |  |  |  |  |  |  |then F
#   |  |  |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |  |else M
#   |  |  |  |  |  |  |  |else F
#   |  |  |  |  |  |else M
#   |  |  |  |  |else if whole weight =< 2.718250036239624:
#   |  |  |  |  |  |then F
#   |  |  |  |  |  |else M
# <------------------------------------------------------------------------------------------------------------->
# Tree Depth:  37
# Accuracy: 1.0

# %% [markdown]
# And there it is...it reports that we can construct a model that has 100% accuracy completely contradicting what we found in our train-test models.
#
# Given the complexity of the model above we can see that basically the model has memorized the entire data set.

# %% [markdown]
# # Train and Test
#
# We have already seen that just using a training set for model evaluation does not work!
#
# Our solution was to split the training data into a training and a test/validation set.
#
# <img src="assets/train-test-data.png" height="200" width="400">

# %% [markdown]
# With that we get the typical performance curves that allow us to evaluate models more realistically.
#
#
# <img src="assets/model-performance-curves.png"  height="200" width="400">

# %% [markdown]
# # Problem!
#
# * Train-testing relies on randomly splitting the training data into two parts.
#
# * If this split just happens to be a ‘bad’ split your results might be biased,
#
# **Solution:** cross-validation

# %% [markdown]
# # Cross-Validation
#
# * In cross-validation we switch the roles of the two sets
# * We evaluate the model on each trial and then take the average
# * This will eliminate a lot of the bias
#
# <img src="assets/2fold-xval.png" height="200" width="400">

# %% [markdown]
# BUT, what if is the split was really bad: e.g. one of the sets does not contain any examples of one of the classes.
#
# **Solution:** create more trials - *n-fold cross-validation*

# %% [markdown]
# As a solution to a single bad split -- perform the split multiple times -- then train and test -- take the average
#
# Example:
# * 5-fold CV - split the training data into 5 splits (folds)
# * Use each fold as a test/validation set and the other folds as training set
# * Multiple splits - even if one is bad it will be balanced out by the others.
#
# <img src="assets/5fold-xval.png" height="200" width="400">

# %%
import pandas as pd
from sklearn import tree
# grab cross validation code
from sklearn.model_selection import cross_val_score

# get data
df = pd.read_csv("assets/iris.csv")
X  = df.drop(['id','Species'],axis=1)
y = df['Species']

# set up the model
model = tree.DecisionTreeClassifier(criterion='entropy', max_depth=2)

# do the 5-fold cross validation
scores = cross_val_score(model, X, y, cv=5)
print("Fold Accuracies: {}".format(scores))
print("Accuracy: {}".format(scores.mean()))
# Out:
# Fold Accuracies: [ 0.93333333  0.96666667  0.9         0.86666667  1.        ]
# Accuracy: 0.9333333333333332

# %% [markdown]
# # Model Evaluation - the Grid Search
#
# Where did our model parameters come from in the above examples?  We searched for them!  Therefore:
#
# * Finding the best model involves searching for (hyper-)parameter values that give you the best testing/cross-validation accuracy.
# * This is usually referred to as the *grid search*.

# %% [markdown]
# Sklearn helps us do that efficiently:
# * Sklearn has a built-in grid search that can optimize the model parameters
# * The tree has two parameters: criterion and depth
# * The grid search will find the optimal value for both of these parameters

# %%
import pandas as pd
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# get data
df = pd.read_csv("assets/iris.csv")
X  = df.drop(['id','Species'],axis=1)
y = df['Species']

# setting up grid search
model = model = tree.DecisionTreeClassifier()
param_grid = {'max_depth': list(range(1,11)),
              'criterion': ['entropy', 'gini']
              }
grid = GridSearchCV(model, param_grid, cv=5)

# performing grid search 
grid.fit(X,y)

# print out what we found
print("Best parameters: {}".format(grid.best_params_))

# print out the best model
print("Best tree:")
tree_print(grid.best_estimator_,X)

# Get the accuracy
# Evaluate the tree
# predicting        
predict_y = grid.best_estimator_.predict(X)
actual_y = y

# accuracy          
print("Accuracy: {}".format(accuracy_score(actual_y, predict_y)))
# Out:
# Best parameters: {'criterion': 'gini', 'max_depth': 3}
# Best tree:
# if Petal.Length =< 2.450000047683716:
#   |then setosa
#   |else if Petal.Width =< 1.75:
#   |  |then if Petal.Length =< 4.949999809265137:
#   |  |  |then versicolor
#   |  |  |else virginica
#   |  |else if Petal.Length =< 4.850000381469727:
#   |  |  |then virginica
#   |  |  |else virginica
# <------->
# Tree Depth:  3
# Accuracy: 0.9733333333333334

# %% [markdown]
# # Model Accuracy Reexamined
#
# Consider a classification problem with two classes, then we observe the following outcomes of a prediction of a suitable classification model:
#
# >true positive (TP)
#
# >true negative (TN)
#
# >false positive (FP), Type I error
#
# >false negative (FN), Type II error
#
# Two types of errors possible!

# %% [markdown]
# # Example
#
# * Consider a database with 165 patients and we have a classifier that predicts disease
# * "yes" would mean they have the disease, and "no" would mean they don't have the disease.
# * 105 patients in the database have the disease, and 60 patients do not
# * the classifier made 15 mistakes and predicted "yes" 110 times, and "no" 55 times
#
# Accuracy = 1 - 15/165 = .91

# %% [markdown]
# 91% Accuracy is pretty good, but assume in this case the classifier made the following predictions:
# * true positives (TP): These are cases in which we predicted yes (they have the disease), and they do have the disease - 100
# * true negatives (TN): We predicted no, and they don't have the disease - 50
# * false positives (FP): We predicted yes, but they don't actually have the disease - 10
# * false negatives (FN): We predicted no, but they actually do have the disease - 5
#
# From a medical point of view the FN are the most concerning - we predict no disease but there is disease.
#
# When building models the data scientist has to be aware of the kind of errors a model commits and their ramifications.

# %% [markdown]
# * We can arrange the predictions in a matrix form
# * Errors will show up as values outside the major diagonal
#
#
# <img src="assets/confusion1.png" height="200" width="400">

# %% [markdown]
# <img src="assets/confusion2.png" height="400" width="800">

# %% [markdown]
# # The Wisconsin Breast Cancer Data Set
#
# The data set is available at [UCI](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)).
# The data set describes benign and malignent tumors based on image measurements.
#
# Let's apply everything we have learned so far: build the best model, and then evaluate it.

# %%
import pandas as pd
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
# get data 
df = pd.read_csv("assets/wdbc.csv")

# %%
df.shape
# Out:
# (569, 32)

# %%
df.head()
# Out:
#    ID  radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0   1    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1   2    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2   3    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3   4    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4   5    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#    concavity1  concave_points1  symmetry1    ...      texture3  perimeter3  \
# 0      0.3001          0.14710     0.2419    ...         17.33      184.60
# 1      0.0869          0.07017     0.1812    ...         23.41      158.80
# 2      0.1974          0.12790     0.2069    ...         25.53      152.50
# 3      0.2414          0.10520     0.2597    ...         26.50       98.87
# 4      0.1980          0.10430     0.1809    ...         16.67      152.20
#
#     area3  smoothness3  compactness3  concavity3  concave_points3  symmetry3  \
# 0  2019.0       0.1622        0.6656      0.7119           0.2654     0.4601
# 1  1956.0       0.1238        0.1866      0.2416           0.1860     0.2750
# 2  1709.0       0.1444        0.4245      0.4504           0.2430     0.3613
# 3   567.7       0.2098        0.8663      0.6869           0.2575     0.6638
# 4  1575.0       0.1374        0.2050      0.4000           0.1625     0.2364
#
#    fractal_dimension3  Diagnosis
# 0             0.11890          M
# 1             0.08902          M
# 2             0.08758          M
# 3             0.17300          M
# 4             0.07678          M
#
# [5 rows x 32 columns]

# %%
# see if our data set is balanced
df['Diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: Diagnosis, dtype: int64

# %%
# create our sklearn data
X  = df.drop(['ID','Diagnosis'],axis=1)
y = df['Diagnosis']

# setting up grid search
model = model = tree.DecisionTreeClassifier()
param_grid = {'max_depth': list(range(1,6)),
              'criterion': ['entropy', 'gini']
              }
grid = GridSearchCV(model, param_grid, cv=5)

# performing grid search 
null = grid.fit(X,y)

# %%
# print out what we found
print("Best parameters: {}".format(grid.best_params_))

# print out the best model
print("Best tree:")
tree_print(grid.best_estimator_,X)
# Out:
# Best parameters: {'criterion': 'entropy', 'max_depth': 4}
# Best tree:
# if perimeter3 =< 105.94999694824219:
#   |then if concave_points3 =< 0.1350499987602234:
#   |  |then if area2 =< 48.974998474121094:
#   |  |  |then if texture3 =< 30.145000457763672:
#   |  |  |  |then B
#   |  |  |  |else B
#   |  |  |else if symmetry3 =< 0.20784999430179596:
#   |  |  |  |then M
#   |  |  |  |else B
#   |  |else if texture3 =< 27.575000762939453:
#   |  |  |then if symmetry3 =< 0.35785001516342163:
#   |  |  |  |then B
#   |  |  |  |else M
#   |  |  |else M
#   |else if perimeter3 =< 117.44999694824219:
#   |  |then if smoothness3 =< 0.13609999418258667:
#   |  |  |then if texture3 =< 25.670000076293945:
#   |  |  |  |then B
#   |  |  |  |else M
#   |  |  |else if area2 =< 16.19499969482422:
#   |  |  |  |then B
#   |  |  |  |else M
#   |  |else if smoothness3 =< 0.09975999593734741:
#   |  |  |then if concavity3 =< 0.22085000574588776:
#   |  |  |  |then B
#   |  |  |  |else M
#   |  |  |else M
# <---------->
# Tree Depth:  4

# %%
# Evaluate the tree
# predicting        
predict_y = grid.best_estimator_.predict(X)
actual_y = y

# accuracy          
print("Accuracy: {}".format(accuracy_score(actual_y, predict_y)))

# build the confusion matrix 
labels = ['B','M']
cm = confusion_matrix(actual_y, predict_y, labels=labels)
cm_df = pd.DataFrame(cm, index=labels, columns=labels)
print("Confusion Matrix:\n{}".format(cm_df))
# Out:
# Accuracy: 0.984182776801406
# Confusion Matrix:
#      B    M
# B  350    7
# M    2  210
